# %%
import os 

URL_RAW = "https://minio.lab.sspcloud.fr/${greatisma}/Dashboard-Airbnb-paris/Processed/listings-clean-2025-04-15.csv"
data_path = os.environ.get("data_path", URL_RAW)

# %%
import s3fs

fs = s3fs.S3FileSystem(client_kwargs={"endpoint_url": "https://minio.lab.sspcloud.fr"})

MY_BUCKET = "greatisma"
CHEMIN = "Dashboard-Airbnb-paris/Processed"
fs.ls(f"s3://{MY_BUCKET}/{CHEMIN}")
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[3], line 7
#       5 MY_BUCKET = "greatisma"
#       6 CHEMIN = "Dashboard-Airbnb-paris/Processed"
# ----> 7 fs.ls(f"s3://{MY_BUCKET}/{CHEMIN}")
#
# File c:\Users\pc\OneDrive\Documents\ENSAE\Mise_en_Prod\Final Project\Dashboard-Airbnb-paris\venv\Lib\site-packages\fsspec\asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File c:\Users\pc\OneDrive\Documents\ENSAE\Mise_en_Prod\Final Project\Dashboard-Airbnb-paris\venv\Lib\site-packages\fsspec\asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
# ...
