# %%
import os 
import pandas as pd

URL_RAW = "https://minio.lab.sspcloud.fr/greatisma/Dashboard-Airbnb-paris/data/raw/listings.csv"
data_path = os.environ.get("data_path", URL_RAW)
df1 = pd.read_csv(data_path)

df1.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  3109  https://www.airbnb.com/rooms/3109  20241206031559   2024-12-07
# 1  5396  https://www.airbnb.com/rooms/5396  20241206031559   2024-12-09
# 2  7397  https://www.airbnb.com/rooms/7397  20241206031559   2024-12-08
# 3  7964  https://www.airbnb.com/rooms/7964  20241206031559   2024-12-09
# 4  9359  https://www.airbnb.com/rooms/9359  20241206031559   2024-12-09
#
#             source                                             name  \
# 0      city scrape                                     zen and calm
# 1      city scrape     Your perfect Paris studio on Île Saint-Louis
# 2      city scrape                 MARAIS - 2ROOMS APT - 2/4 PEOPLE
# 3  previous scrape                     Sunny apartment with balcony
# 4      city scrape  Cozy, Central Paris: WALK or VELIB EVERYWHERE !
#
#                                          description  \
# 0  Lovely Appartment with one bedroom with a Quee...
# ...

# %%
URL_RAW = "https://minio.lab.sspcloud.fr/greatisma/Dashboard-Airbnb-paris/data/processed/listings-clean-2025-04-15.csv"
data_path = os.environ.get("data_path", URL_RAW)
df = pd.read_csv(data_path)

df.head()
# Out:
#      id                                             name  host_id   host_name  \
# 0  3109                                     zen and calm     3631        Anne
# 1  5396     Your perfect Paris studio on Île Saint-Louis     7903      Borzou
# 2  7397                 MARAIS - 2ROOMS APT - 2/4 PEOPLE     2626      Franck
# 3  9359  Cozy, Central Paris: WALK or VELIB EVERYWHERE !    28422  Bernadette
# 4  9952                        Paris petit coin douillet    33534   Elisabeth
#
#   neighbourhood_cleansed  latitude  longitude        room_type  price  \
# 0           Observatoire  48.83191    2.31870  Entire home/apt  100.0
# 1         Hôtel-de-Ville  48.85247    2.35835  Entire home/apt   88.0
# 2         Hôtel-de-Ville  48.85909    2.35315  Entire home/apt  136.0
# 3                 Louvre  48.85898    2.34701  Entire home/apt   75.0
# 4             Popincourt  48.86238    2.36957  Entire home/apt  150.0
#
# ...

# %%
df1.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
print(df1[['neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'host_neighbourhood']].head(10))
# Out:
#              neighbourhood neighbourhood_cleansed  \
# 0  Neighborhood highlights           Observatoire
# 1  Neighborhood highlights         Hôtel-de-Ville
# 2                      NaN         Hôtel-de-Ville
# 3                      NaN                  Opéra
# 4                      NaN                 Louvre
# 5  Neighborhood highlights             Popincourt
# 6  Neighborhood highlights      Buttes-Montmartre
# 7  Neighborhood highlights             Popincourt
# 8  Neighborhood highlights               Gobelins
# 9                      NaN             Popincourt
#
#    neighbourhood_group_cleansed                 host_neighbourhood
# 0                           NaN                             Alésia
# 1                           NaN       Saint-Paul - Ile Saint-Louis
# 2                           NaN                          Le Marais
# 3                           NaN       Gare du Nord - Gare de I'Est
# 4                           NaN  Châtelet - Les Halles - Beaubourg
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
mc anonymous set download s3/${BUCKET_PERSONNEL}/Dashboard-Airbnb-paris/data/processed/
